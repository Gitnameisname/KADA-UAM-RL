# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = 'train_result_2023-08-11_063604.txt'
with open(f'./results/{filename}') as f:
    lines = f.readlines()

# %%
episode = []
timestep = []
reward = []
for i, line in enumerate(lines):
    if i % 4 == 0:
        episode.append(int(line.split(':')[1].strip()))
    if i % 4 == 1:
        timestep.append(int(line.split(':')[1].strip()))
    if i % 4 == 2:
        reward.append(float(line.split(':')[1].strip()))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 6
#       4 for i, line in enumerate(lines):
#       5     if i % 4 == 0:
# ----> 6         episode.append(int(line.split(':')[1].strip()))
#       7     if i % 4 == 1:
#       8         timestep.append(int(line.split(':')[1].strip()))
#
# IndexError: list index out of range

# %%
results = {
    "episode": episode,
    "timestep": timestep,
    "reward": reward
    }

# %%
df = pd.DataFrame(results)
df.to_excel('./results/')
# Out:
#      episode  timestep        reward
# 0          0        25     32.000069
# 1          1        43     41.794727
# 2          2        71     61.500096
# 3          3        80     56.000114
# 4          4        17     79.500080
# ..       ...       ...           ...
# 987      995      6672  48513.970845
# 988      996         0  46073.972193
# 989      997      3600  47056.397994
# 990      998         0  45858.609513
# 991      999         0  47301.836798
#
# [992 rows x 3 columns]

# %%
df.plot(x='episode', y='timestep')
plt.title('Episode vs Time step')
plt.xlabel('Episode')
plt.ylabel('Time Step')
# Out:
# Text(0, 0.5, 'Time Step')

# %%
df.plot(x='episode', y='reward')
plt.title('Episode vs reward')
plt.xlabel('Episode')
plt.ylabel('reward')
# Out:
# Text(0, 0.5, 'reward')
